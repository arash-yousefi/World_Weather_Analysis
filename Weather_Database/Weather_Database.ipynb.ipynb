# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
coordinates

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        # YOUR CODE HERE

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a595c4d680ef39c17b2e0c508be3a63a

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        weather_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "weather_description": weather_description
                         })
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | george
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | akdepe
# Processing Record 15 of Set 1 | esmeraldas
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | dinghai
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | alice springs
# Processing Record 22 of Set 1 | bukachacha
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | shache
# Processing Record 28 of Set 1 | timizart
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 31 of Set 1 | kashi
# Processing Record 32 of Set 1 | poli
# Processing Record 33 of Set 1 | ormara
# Processing Record 34 of Set 1 | hofn
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | tura
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | sabanagrande
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | bud
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | flensburg
# Processing Record 44 of Set 1 | tsimlyansk
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | loukhi
# Processing Record 47 of Set 1 | miyang
# Processing Record 48 of Set 1 | sivaki
# Processing Record 49 of Set 1 | vostok
# Processing Record 50 of Set 1 | nouadhibou
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | anito
# Processing Record 4 of Set 2 | pont-audemer
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | hay river
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | cayenne
# Processing Record 14 of Set 2 | ler
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | monroe
# Processing Record 18 of Set 2 | havre-saint-pierre
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | yulara
# Processing Record 21 of Set 2 | qasigiannguit
# Processing Record 22 of Set 2 | sehithwa
# Processing Record 23 of Set 2 | atar
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | santa cruz
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 30 of Set 2 | kieta
# Processing Record 31 of Set 2 | plettenberg bay
# Processing Record 32 of Set 2 | huescar
# Processing Record 33 of Set 2 | pandharpur
# Processing Record 34 of Set 2 | santiago
# Processing Record 35 of Set 2 | rio gallegos
# Processing Record 36 of Set 2 | chilia veche
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | port blair
# Processing Record 39 of Set 2 | zhigansk
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | batticaloa
# Processing Record 42 of Set 2 | teya
# Processing Record 43 of Set 2 | camacha
# Processing Record 44 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 2 | chom bung
# City not found. Skipping...
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | faxinal
# Processing Record 48 of Set 2 | conceicao do araguaia
# Processing Record 49 of Set 2 | saint-joseph
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | tsabong
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | turayf
# Processing Record 5 of Set 3 | mount isa
# Processing Record 6 of Set 3 | kloulklubed
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | granville
# Processing Record 9 of Set 3 | villa del rosario
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | san jose
# Processing Record 12 of Set 3 | codrington
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | chapais
# Processing Record 15 of Set 3 | high rock
# Processing Record 16 of Set 3 | svetlogorsk
# Processing Record 17 of Set 3 | nyurba
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | sorong
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | nyamuswa
# Processing Record 22 of Set 3 | boguchany
# Processing Record 23 of Set 3 | sterling
# Processing Record 24 of Set 3 | trudarmeyskiy
# Processing Record 25 of Set 3 | saint-augustin
# Processing Record 26 of Set 3 | ilmajoki
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | palu
# Processing Record 29 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 3 | fecamp
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | yerbogachen
# Processing Record 34 of Set 3 | prainha
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | gangarampur
# Processing Record 37 of Set 3 | turkistan
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | jamestown
# Processing Record 40 of Set 3 | batagay-alyta
# Processing Record 41 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 42 of Set 3 | amarante do maranhao
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | sovetskiy
# Processing Record 45 of Set 3 | juntas
# Processing Record 46 of Set 3 | santa rosa
# Processing Record 47 of Set 3 | wanning
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | verkhoyansk
# Processing Record 50 of Set 3 | nadym
# Processing Record 1 of Set 4 | ullapool
# Processing Record 2 of Set 4 | port-gentil
# Processing Record 3 of Set 4 | nobres
# Processing Record 4 of Set 4 | biloli
# Processing Record 5 of Set 4 | mahibadhoo
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | pouembout
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | praia
# Processing Record 11 of Set 4 | bereda
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | lindi
# Processing Record 14 of Set 4 | poum
# Processing Record 15 of Set 4 | faya
# Processing Record 16 of Set 4 | labuan
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | komsomolskiy
# Processing Record 23 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 4 | yuli
# Processing Record 25 of Set 4 | nikolskoye
# Processing Record 26 of Set 4 | dicabisagan
# Processing Record 27 of Set 4 | sanandaj
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | henties bay
# Processing Record 30 of Set 4 | megion
# Processing Record 31 of Set 4 | clyde river
# Processing Record 32 of Set 4 | college
# Processing Record 33 of Set 4 | ust-maya
# Processing Record 34 of Set 4 | dulce grande
# Processing Record 35 of Set 4 | chokurdakh
# Processing Record 36 of Set 4 | masuda
# Processing Record 37 of Set 4 | korla
# Processing Record 38 of Set 4 | tiznit
# Processing Record 39 of Set 4 | makaryev
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | moussoro
# Processing Record 44 of Set 4 | nago
# Processing Record 45 of Set 4 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 46 of Set 4 | malaya vishera
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | ostersund
# Processing Record 49 of Set 4 | arman
# Processing Record 50 of Set 4 | coquimbo
# Processing Record 1 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 5 | coro
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | ponta do sol
# Processing Record 5 of Set 5 | wum
# Processing Record 6 of Set 5 | port pirie
# Processing Record 7 of Set 5 | cabedelo
# Processing Record 8 of Set 5 | tevriz
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | nouakchott
# Processing Record 11 of Set 5 | kathmandu
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | half moon bay
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | gobabis
# Processing Record 16 of Set 5 | butaritari
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | entre rios
# Processing Record 19 of Set 5 | sandwick
# Processing Record 20 of Set 5 | klaksvik
# Processing Record 21 of Set 5 | xianyang
# Processing Record 22 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 5 | tuktoyaktuk
# Processing Record 24 of Set 5 | nome
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | sur
# Processing Record 27 of Set 5 | la ronge
# Processing Record 28 of Set 5 | kungurtug
# Processing Record 29 of Set 5 | ballina
# Processing Record 30 of Set 5 | pucara
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | omboue
# Processing Record 33 of Set 5 | starobesheve
# Processing Record 34 of Set 5 | richards bay
# Processing Record 35 of Set 5 | ketchikan
# Processing Record 36 of Set 5 | praya
# Processing Record 37 of Set 5 | ajdabiya
# Processing Record 38 of Set 5 | sao gabriel da cachoeira
# Processing Record 39 of Set 5 | petatlan
# Processing Record 40 of Set 5 | chuy
# Processing Record 41 of Set 5 | puerto narino
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 44 of Set 5 | pavelets
# Processing Record 45 of Set 5 | nishihara
# Processing Record 46 of Set 5 | leinefelde
# Processing Record 47 of Set 5 | huarmey
# Processing Record 48 of Set 5 | badaojiang
# City not found. Skipping...
# Processing Record 49 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 50 of Set 5 | carutapera
# Processing Record 1 of Set 6 | saint-ambroise
# Processing Record 2 of Set 6 | stornoway
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | necochea
# Processing Record 5 of Set 6 | neiafu
# Processing Record 6 of Set 6 | luderitz
# Processing Record 7 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | kant
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | douglas
# Processing Record 12 of Set 6 | itupiranga
# Processing Record 13 of Set 6 | hokitika
# Processing Record 14 of Set 6 | ixtapa
# Processing Record 15 of Set 6 | port alfred
# Processing Record 16 of Set 6 | havelock
# Processing Record 17 of Set 6 | sakaiminato
# Processing Record 18 of Set 6 | haines junction
# Processing Record 19 of Set 6 | port hedland
# Processing Record 20 of Set 6 | tsuruoka
# Processing Record 21 of Set 6 | hualmay
# Processing Record 22 of Set 6 | beian
# Processing Record 23 of Set 6 | asau
# Processing Record 24 of Set 6 | lakatoro
# Processing Record 25 of Set 6 | ukiah
# Processing Record 26 of Set 6 | adrar
# Processing Record 27 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 6 | kabugao
# Processing Record 29 of Set 6 | inta
# Processing Record 30 of Set 6 | vila franca do campo
# Processing Record 31 of Set 6 | puerto lempira
# Processing Record 32 of Set 6 | chlorakas
# Processing Record 33 of Set 6 | inhambane
# Processing Record 34 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 6 | ilulissat
# Processing Record 37 of Set 6 | galich
# Processing Record 38 of Set 6 | canberra
# Processing Record 39 of Set 6 | gamba
# Processing Record 40 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 41 of Set 6 | goksun
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | ouallam
# Processing Record 45 of Set 6 | lumsden
# Processing Record 46 of Set 6 | vite
# Processing Record 47 of Set 6 | hobyo
# Processing Record 48 of Set 6 | masvingo
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 6 | tabuk
# Processing Record 1 of Set 7 | leh
# Processing Record 2 of Set 7 | hasaki
# Processing Record 3 of Set 7 | inuvik
# Processing Record 4 of Set 7 | clinton
# Processing Record 5 of Set 7 | liverpool
# Processing Record 6 of Set 7 | qaqortoq
# Processing Record 7 of Set 7 | ho chi minh city
# Processing Record 8 of Set 7 | lhuntshi
# City not found. Skipping...
# Processing Record 9 of Set 7 | osakarovka
# Processing Record 10 of Set 7 | kot samaba
# Processing Record 11 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 12 of Set 7 | bambous virieux
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | hami
# Processing Record 15 of Set 7 | karratha
# Processing Record 16 of Set 7 | jumla
# Processing Record 17 of Set 7 | placido de castro
# Processing Record 18 of Set 7 | castro
# Processing Record 19 of Set 7 | xiuyan
# Processing Record 20 of Set 7 | george town
# Processing Record 21 of Set 7 | sangar
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | mananara
# Processing Record 24 of Set 7 | roebourne
# Processing Record 25 of Set 7 | marzuq
# Processing Record 26 of Set 7 | clydebank
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | grindavik
# Processing Record 29 of Set 7 | xining
# Processing Record 30 of Set 7 | maraa
# Processing Record 31 of Set 7 | port hardy
# Processing Record 32 of Set 7 | kenora
# Processing Record 33 of Set 7 | port moresby
# Processing Record 34 of Set 7 | naze
# Processing Record 35 of Set 7 | beloha
# Processing Record 36 of Set 7 | fuyu
# Processing Record 37 of Set 7 | igarka
# Processing Record 38 of Set 7 | tiksi
# Processing Record 39 of Set 7 | lai
# Processing Record 40 of Set 7 | huangmei
# Processing Record 41 of Set 7 | itoman
# Processing Record 42 of Set 7 | jucas
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | saint combs
# City not found. Skipping...
# Processing Record 45 of Set 7 | launceston
# Processing Record 46 of Set 7 | noumea
# Processing Record 47 of Set 7 | haghartsin
# Processing Record 48 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 8 | lazaro cardenas
# Processing Record 2 of Set 8 | livingstonia
# Processing Record 3 of Set 8 | ivanava
# Processing Record 4 of Set 8 | mountain home
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 7 of Set 8 | warri
# Processing Record 8 of Set 8 | ligayan
# Processing Record 9 of Set 8 | provideniya
# Processing Record 10 of Set 8 | paka
# Processing Record 11 of Set 8 | lichuan
# Processing Record 12 of Set 8 | maloy
# Processing Record 13 of Set 8 | palmer
# Processing Record 14 of Set 8 | terrace
# Processing Record 15 of Set 8 | micheweni
# Processing Record 16 of Set 8 | jever
# Processing Record 17 of Set 8 | kidal
# Processing Record 18 of Set 8 | anchorage
# Processing Record 19 of Set 8 | machali
# Processing Record 20 of Set 8 | aberdeen
# Processing Record 21 of Set 8 | deputatskiy
# Processing Record 22 of Set 8 | roald
# Processing Record 23 of Set 8 | meulaboh
# Processing Record 24 of Set 8 | tual
# Processing Record 25 of Set 8 | sergeyevka
# Processing Record 26 of Set 8 | barabai
# Processing Record 27 of Set 8 | makakilo city
# Processing Record 28 of Set 8 | vestmannaeyjar
# Processing Record 29 of Set 8 | broome
# Processing Record 30 of Set 8 | benghazi
# Processing Record 31 of Set 8 | sao francisco
# Processing Record 32 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 8 | ekuvukeni
# Processing Record 34 of Set 8 | sioux lookout
# Processing Record 35 of Set 8 | manzil salim
# Processing Record 36 of Set 8 | sumenep
# Processing Record 37 of Set 8 | ouadda
# Processing Record 38 of Set 8 | abbeville
# Processing Record 39 of Set 8 | la rioja
# Processing Record 40 of Set 8 | tezu
# Processing Record 41 of Set 8 | ahipara
# Processing Record 42 of Set 8 | margate
# Processing Record 43 of Set 8 | paramonga
# Processing Record 44 of Set 8 | akyab
# Processing Record 45 of Set 8 | chigorodo
# Processing Record 46 of Set 8 | mnogovershinnyy
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | vila velha
# Processing Record 50 of Set 8 | beroroha
# Processing Record 1 of Set 9 | boa vista
# Processing Record 2 of Set 9 | japura
# Processing Record 3 of Set 9 | marawi
# Processing Record 4 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 9 | qunduz
# Processing Record 6 of Set 9 | marystown
# Processing Record 7 of Set 9 | mao
# Processing Record 8 of Set 9 | oistins
# Processing Record 9 of Set 9 | bad windsheim
# Processing Record 10 of Set 9 | bay roberts
# Processing Record 11 of Set 9 | dingle
# Processing Record 12 of Set 9 | saint-georges
# Processing Record 13 of Set 9 | maryville
# Processing Record 14 of Set 9 | swift current
# Processing Record 15 of Set 9 | handlova
# Processing Record 16 of Set 9 | ibra
# Processing Record 17 of Set 9 | angoram
# Processing Record 18 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 9 | maun
# Processing Record 20 of Set 9 | angoche
# Processing Record 21 of Set 9 | flin flon
# Processing Record 22 of Set 9 | hambantota
# Processing Record 23 of Set 9 | biltine
# Processing Record 24 of Set 9 | touros
# Processing Record 25 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 9 | tambura
# Processing Record 27 of Set 9 | nicholasville
# Processing Record 28 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 9 | ushumun
# Processing Record 30 of Set 9 | chiradzulu
# Processing Record 31 of Set 9 | khvoynaya
# Processing Record 32 of Set 9 | buchanan
# Processing Record 33 of Set 9 | teknaf
# Processing Record 34 of Set 9 | thayetmyo
# Processing Record 35 of Set 9 | poronaysk
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | churapcha
# Processing Record 38 of Set 9 | waingapu
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | tessalit
# Processing Record 41 of Set 9 | eyl
# Processing Record 42 of Set 9 | taunggyi
# Processing Record 43 of Set 9 | kiama
# Processing Record 44 of Set 9 | taoudenni
# Processing Record 45 of Set 9 | luzon
# Processing Record 46 of Set 9 | san quintin
# Processing Record 47 of Set 9 | kaitangata
# Processing Record 48 of Set 9 | kailua
# Processing Record 49 of Set 9 | bambari
# Processing Record 50 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 10 | smithers
# Processing Record 2 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 10 | totma
# Processing Record 4 of Set 10 | krechevitsy
# Processing Record 5 of Set 10 | weligama
# Processing Record 6 of Set 10 | bayan
# Processing Record 7 of Set 10 | lagos
# Processing Record 8 of Set 10 | neryungri
# Processing Record 9 of Set 10 | mutis
# Processing Record 10 of Set 10 | porto novo
# Processing Record 11 of Set 10 | mackay
# Processing Record 12 of Set 10 | brae
# Processing Record 13 of Set 10 | nioki
# Processing Record 14 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 10 | honiara
# Processing Record 16 of Set 10 | namie
# Processing Record 17 of Set 10 | belyy yar
# Processing Record 18 of Set 10 | teguise
# Processing Record 19 of Set 10 | tacuarembo
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | tuatapere
# Processing Record 22 of Set 10 | aktau
# Processing Record 23 of Set 10 | ancud
# Processing Record 24 of Set 10 | bara
# Processing Record 25 of Set 10 | salalah
# Processing Record 26 of Set 10 | belaya gora
# Processing Record 27 of Set 10 | chitrakonda
# Processing Record 28 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 10 | bubaque
# Processing Record 30 of Set 10 | labytnangi
# Processing Record 31 of Set 10 | filadelfia
# Processing Record 32 of Set 10 | aguimes
# Processing Record 33 of Set 10 | mahroni
# Processing Record 34 of Set 10 | bereslavka
# Processing Record 35 of Set 10 | tromso
# Processing Record 36 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 10 | padang
# Processing Record 39 of Set 10 | lisala
# Processing Record 40 of Set 10 | axim
# Processing Record 41 of Set 10 | muros
# Processing Record 42 of Set 10 | vanimo
# Processing Record 43 of Set 10 | manica
# Processing Record 44 of Set 10 | two rivers
# Processing Record 45 of Set 10 | fuengirola
# Processing Record 46 of Set 10 | garissa
# Processing Record 47 of Set 10 | mandalgovi
# Processing Record 48 of Set 10 | alofi
# Processing Record 49 of Set 10 | pochutla
# Processing Record 50 of Set 10 | anadyr
# Processing Record 1 of Set 11 | raga
# Processing Record 2 of Set 11 | kousseri
# Processing Record 3 of Set 11 | mocuba
# Processing Record 4 of Set 11 | bandar-e lengeh
# Processing Record 5 of Set 11 | jiaojiang
# Processing Record 6 of Set 11 | matias barbosa
# Processing Record 7 of Set 11 | thabazimbi
# Processing Record 8 of Set 11 | zavitinsk
# Processing Record 9 of Set 11 | oranjemund
# Processing Record 10 of Set 11 | pontes e lacerda
# Processing Record 11 of Set 11 | sao caetano de odivelas
# Processing Record 12 of Set 11 | tarko-sale
# Processing Record 13 of Set 11 | zittau
# Processing Record 14 of Set 11 | vrangel
# Processing Record 15 of Set 11 | fonte boa
# Processing Record 16 of Set 11 | hachinohe
# Processing Record 17 of Set 11 | yakeshi
# Processing Record 18 of Set 11 | mezen
# Processing Record 19 of Set 11 | longyan
# Processing Record 20 of Set 11 | pingyi
# Processing Record 21 of Set 11 | san carlos de bariloche
# Processing Record 22 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 23 of Set 11 | ternovka
# Processing Record 24 of Set 11 | limbazi
# Processing Record 25 of Set 11 | portel
# Processing Record 26 of Set 11 | eirunepe
# Processing Record 27 of Set 11 | katsuura
# Processing Record 28 of Set 11 | jaque
# Processing Record 29 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 11 | cumbum
# Processing Record 31 of Set 11 | fare
# Processing Record 32 of Set 11 | benjamin constant
# Processing Record 33 of Set 11 | san andres
# Processing Record 34 of Set 11 | pitimbu
# Processing Record 35 of Set 11 | miraflores
# Processing Record 36 of Set 11 | viedma
# Processing Record 37 of Set 11 | kutum
# Processing Record 38 of Set 11 | puerto maldonado
# Processing Record 39 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 40 of Set 11 | marovoay
# Processing Record 41 of Set 11 | cockburn town
# Processing Record 42 of Set 11 | kununurra
# Processing Record 43 of Set 11 | tukrah
# Processing Record 44 of Set 11 | puerto suarez
# Processing Record 45 of Set 11 | vila
# Processing Record 46 of Set 11 | sapao
# City not found. Skipping...
# Processing Record 47 of Set 11 | doha
# Processing Record 48 of Set 11 | bagli
# Processing Record 49 of Set 11 | wellington
# Processing Record 50 of Set 11 | ilhabela
# Processing Record 1 of Set 12 | uruzgan
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | amahai
# Processing Record 4 of Set 12 | cacheu
# Processing Record 5 of Set 12 | anaco
# Processing Record 6 of Set 12 | zeya
# Processing Record 7 of Set 12 | cristalina
# Processing Record 8 of Set 12 | rantepao
# Processing Record 9 of Set 12 | severobaykalsk
# Processing Record 10 of Set 12 | magadan
# Processing Record 11 of Set 12 | leningradskiy
# Processing Record 12 of Set 12 | tambopata
# Processing Record 13 of Set 12 | hammerfest
# Processing Record 14 of Set 12 | kamenka
# Processing Record 15 of Set 12 | guerrero negro
# Processing Record 16 of Set 12 | los llanos de aridane
# Processing Record 17 of Set 12 | barra do corda
# Processing Record 18 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 19 of Set 12 | tautira
# Processing Record 20 of Set 12 | orocue
# Processing Record 21 of Set 12 | sarahan
# Processing Record 22 of Set 12 | marmora
# Processing Record 23 of Set 12 | wilmington
# Processing Record 24 of Set 12 | aksu
# Processing Record 25 of Set 12 | lamballe
# Processing Record 26 of Set 12 | dutlwe
# Processing Record 27 of Set 12 | luanda
# Processing Record 28 of Set 12 | wajima
# Processing Record 29 of Set 12 | beihai
# Processing Record 30 of Set 12 | slave lake
# Processing Record 31 of Set 12 | shitkino
# Processing Record 32 of Set 12 | palana
# Processing Record 33 of Set 12 | antalya
# Processing Record 34 of Set 12 | nabire
# Processing Record 35 of Set 12 | acarau
# Processing Record 36 of Set 12 | boyolangu
# Processing Record 37 of Set 12 | manado
# Processing Record 38 of Set 12 | assomada
# Processing Record 39 of Set 12 | paamiut
# Processing Record 40 of Set 12 | santa maria
# Processing Record 41 of Set 12 | mehamn
# Processing Record 42 of Set 12 | kemijarvi
# Processing Record 43 of Set 12 | santa flavia
# Processing Record 44 of Set 12 | wattegama
# Processing Record 45 of Set 12 | mayumba
# Processing Record 46 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 47 of Set 12 | polunochnoye
# Processing Record 48 of Set 12 | weston
# Processing Record 49 of Set 12 | ondangwa
# Processing Record 50 of Set 12 | vallenar
# Processing Record 1 of Set 13 | namibe
# Processing Record 2 of Set 13 | constitucion
# Processing Record 3 of Set 13 | byron bay
# Processing Record 4 of Set 13 | valdivia
# Processing Record 5 of Set 13 | laguna beach
# Processing Record 6 of Set 13 | inirida
# Processing Record 7 of Set 13 | malakal
# Processing Record 8 of Set 13 | san luis
# Processing Record 9 of Set 13 | ucluelet
# Processing Record 10 of Set 13 | kyra
# Processing Record 11 of Set 13 | beira
# Processing Record 12 of Set 13 | tazovskiy
# Processing Record 13 of Set 13 | kudahuvadhoo
# Processing Record 14 of Set 13 | kez
# Processing Record 15 of Set 13 | kidero
# Processing Record 16 of Set 13 | san ramon de la nueva oran
# Processing Record 17 of Set 13 | karagay
# Processing Record 18 of Set 13 | adelaide
# Processing Record 19 of Set 13 | hit
# Processing Record 20 of Set 13 | chimbote
# Processing Record 21 of Set 13 | andenes
# Processing Record 22 of Set 13 | vitim
# Processing Record 23 of Set 13 | comodoro rivadavia
# Processing Record 24 of Set 13 | buluang
# Processing Record 25 of Set 13 | saint joseph
# Processing Record 26 of Set 13 | tekeli
# Processing Record 27 of Set 13 | souillac
# Processing Record 28 of Set 13 | strezhevoy
# Processing Record 29 of Set 13 | karasuk
# Processing Record 30 of Set 13 | simbahan
# Processing Record 31 of Set 13 | khasan
# Processing Record 32 of Set 13 | norilsk
# Processing Record 33 of Set 13 | lasa
# Processing Record 34 of Set 13 | tanjong tokong
# City not found. Skipping...
# Processing Record 35 of Set 13 | vernon
# Processing Record 36 of Set 13 | dhidhdhoo
# Processing Record 37 of Set 13 | brainerd
# Processing Record 38 of Set 13 | solnechnyy
# Processing Record 39 of Set 13 | berdigestyakh
# Processing Record 40 of Set 13 | lata
# Processing Record 41 of Set 13 | kralendijk
# Processing Record 42 of Set 13 | boueni
# Processing Record 43 of Set 13 | manama
# Processing Record 44 of Set 13 | saint-pierre
# Processing Record 45 of Set 13 | lukiv
# Processing Record 46 of Set 13 | tecoanapa
# Processing Record 47 of Set 13 | west kilbride
# Processing Record 48 of Set 13 | lhokseumawe
# Processing Record 49 of Set 13 | sembakung
# Processing Record 50 of Set 13 | kurtamysh
# Processing Record 1 of Set 14 | patiya
# Processing Record 2 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 3 of Set 14 | inhapim
# Processing Record 4 of Set 14 | shetpe
# Processing Record 5 of Set 14 | lumeje
# Processing Record 6 of Set 14 | mae chan
# Processing Record 7 of Set 14 | samana
# Processing Record 8 of Set 14 | machiques
# Processing Record 9 of Set 14 | emerald
# Processing Record 10 of Set 14 | trzebiatow
# Processing Record 11 of Set 14 | katangli
# Processing Record 12 of Set 14 | gorontalo
# Processing Record 13 of Set 14 | sotnikovskoye
# Processing Record 14 of Set 14 | samarai
# Processing Record 15 of Set 14 | vinzili
# Processing Record 16 of Set 14 | sola
# Processing Record 17 of Set 14 | san lawrenz
# Processing Record 18 of Set 14 | mandera
# Processing Record 19 of Set 14 | camana
# Processing Record 20 of Set 14 | atambua
# Processing Record 21 of Set 14 | russell
# Processing Record 22 of Set 14 | pilna
# Processing Record 23 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 14 | kadirli
# Processing Record 25 of Set 14 | ilek
# Processing Record 26 of Set 14 | caibarien
# Processing Record 27 of Set 14 | tanout
# Processing Record 28 of Set 14 | roma
# Processing Record 29 of Set 14 | colwyn bay
# Processing Record 30 of Set 14 | klyuchi
# Processing Record 31 of Set 14 | novobiryusinskiy
# Processing Record 32 of Set 14 | winnemucca
# Processing Record 33 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 34 of Set 14 | szekkutas
# Processing Record 35 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 36 of Set 14 | ambilobe
# Processing Record 37 of Set 14 | fuzhou
# Processing Record 38 of Set 14 | kimbe
# Processing Record 39 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 14 | angra
# City not found. Skipping...
# Processing Record 41 of Set 14 | filingue
# Processing Record 42 of Set 14 | borovoy
# Processing Record 43 of Set 14 | belmonte
# Processing Record 44 of Set 14 | paraiso
# Processing Record 45 of Set 14 | saint-raphael
# Processing Record 46 of Set 14 | trapani
# Processing Record 47 of Set 14 | dunedin
# Processing Record 48 of Set 14 | kinablangan
# Processing Record 49 of Set 14 | san policarpo
# Processing Record 50 of Set 14 | maningrida
# Processing Record 1 of Set 15 | sungairaya
# Processing Record 2 of Set 15 | hamilton
# Processing Record 3 of Set 15 | bend
# Processing Record 4 of Set 15 | houma
# Processing Record 5 of Set 15 | opuwo
# Processing Record 6 of Set 15 | mbandaka
# Processing Record 7 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 15 | innisfail
# Processing Record 9 of Set 15 | banikoara
# Processing Record 10 of Set 15 | zhongshu
# Processing Record 11 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 15 | abu samrah
# Processing Record 13 of Set 15 | kenai
# Processing Record 14 of Set 15 | gat
# Processing Record 15 of Set 15 | uyskoye
# Processing Record 16 of Set 15 | bang saphan
# Processing Record 17 of Set 15 | chuari khas
# Processing Record 18 of Set 15 | cosala
# Processing Record 19 of Set 15 | alugan
# Processing Record 20 of Set 15 | aswan
# Processing Record 21 of Set 15 | saint-louis
# Processing Record 22 of Set 15 | mindelo
# Processing Record 23 of Set 15 | sabha
# Processing Record 24 of Set 15 | zhanaozen
# Processing Record 25 of Set 15 | kuandian
# Processing Record 26 of Set 15 | okha
# Processing Record 27 of Set 15 | ossora
# Processing Record 28 of Set 15 | sainte-maxime
# Processing Record 29 of Set 15 | kananga
# Processing Record 30 of Set 15 | mozarlandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Saskylakh  71.9167  114.0833    -28.71        99          60        7.18
# 1    Mataura -46.1927  168.8643     64.26        60          93        7.47
# 2       Hilo  19.7297 -155.0900     82.13        69          40       11.50
# 3    Qaanaaq  77.4840  -69.3632     -9.54        55          77        6.22
# 4     Albany  42.6001  -73.9662     32.27        62          75        5.55
# 5      Bluff -46.6000  168.3333     60.67        73          20       11.39
# 6      Sitka  57.0531 -135.3300     42.69        81          75        3.44
# 7     Atuona  -9.8000 -139.0333     78.69        72         100       16.87
# 8    Te Anau -45.4167  167.7167     68.67        47           6        2.91
# 9     Barrow  71.2906 -156.7887    -25.04       100         100       13.18
#
#   Country                 Date weather_description
# 0      RU  2023-01-16 22:47:12       broken clouds
# 1      NZ  2023-01-16 22:50:13     overcast clouds
# 2      US  2023-01-16 22:48:57    scattered clouds
# 3      GL  2023-01-16 22:51:54       broken clouds
# 4      US  2023-01-16 22:51:55       broken clouds
# 5      NZ  2023-01-16 22:54:21          few clouds
# 6      US  2023-01-16 22:51:56          light rain
# 7      PF  2023-01-16 22:54:22     overcast clouds
# 8      NZ  2023-01-16 22:54:22           clear sky
# 9      US  2023-01-16 22:54:23     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'weather_description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness",  "Wind Speed", "weather_description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Saskylakh      RU  71.9167  114.0833    -28.71        99          60
# 1          Mataura      NZ -46.1927  168.8643     64.26        60          93
# 2             Hilo      US  19.7297 -155.0900     82.13        69          40
# 3          Qaanaaq      GL  77.4840  -69.3632     -9.54        55          77
# 4           Albany      US  42.6001  -73.9662     32.27        62          75
# ..             ...     ...      ...       ...       ...       ...         ...
# 664           Okha      RU  53.5739  142.9478    -36.94        99          34
# 665         Ossora      RU  59.2353  163.0719     -8.23        88          78
# 666  Sainte-Maxime      FR  43.3000    6.6333     50.02        56         100
# 667        Kananga      CD  -5.8958   22.4178     68.16        98         100
# 668    Mozarlandia      BR -14.7447  -50.5706     74.17        89          73
#
#      Wind Speed weather_description
# 0          7.18       broken clouds
# 1          7.47     overcast clouds
# 2         11.50    scattered clouds
# 3          6.22       broken clouds
# 4          5.55       broken clouds
# ..          ...                 ...
# 664        6.15    scattered clouds
# 665        5.19       broken clouds
# 666       12.01     overcast clouds
# 667        3.02          light rain
# 668        3.98       broken clouds
#
# [669 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# weather_description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "/Users/arashyousefi/Desktop/Analysis Project/Module-6/Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
