# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 

# YOUR CODE HERE
city_data_df = pd.read_csv("/Users/arashyousefi/Desktop/Analysis Project/Module-6/Weather_Database/WeatherPy_Database.csv")
# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#      City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0      Saskylakh      RU  71.9167  114.0833    -28.71        99
# 1          1        Mataura      NZ -46.1927  168.8643     64.26        60
# 2          2           Hilo      US  19.7297 -155.0900     82.13        69
# 3          3        Qaanaaq      GL  77.4840  -69.3632     -9.54        55
# 4          4         Albany      US  42.6001  -73.9662     32.27        62
# ..       ...            ...     ...      ...       ...       ...       ...
# 664      664           Okha      RU  53.5739  142.9478    -36.94        99
# 665      665         Ossora      RU  59.2353  163.0719     -8.23        88
# 666      666  Sainte-Maxime      FR  43.3000    6.6333     50.02        56
# 667      667        Kananga      CD  -5.8958   22.4178     68.16        98
# 668      668    Mozarlandia      BR -14.7447  -50.5706     74.17        89
#
#      Cloudiness  Wind Speed weather_description
# 0            60        7.18       broken clouds
# 1            93        7.47     overcast clouds
# 2            40       11.50    scattered clouds
# 3            77        6.22       broken clouds
# 4            75        5.55       broken clouds
# ..          ...         ...                 ...
# 664          34        6.15    scattered clouds
# 665          78        5.19       broken clouds
# 666         100       12.01     overcast clouds
# 667         100        3.02          light rain
# 668          73        3.98       broken clouds
#
# [669 rows x 10 columns]

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
# YOUR CODE HERE
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
# YOUR CODE HERE
preferred_cities_df= city_data_df.loc [
(min_temp<= city_data_df["Max Temp"]) & (max_temp>= city_data_df["Max Temp"])
]
# Display sample data
preferred_cities_df
# YOUR CODE HERE
# Out:
#      City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 2          2           Hilo      US  19.7297 -155.0900     82.13        69
# 7          7         Atuona      PF  -9.8000 -139.0333     78.69        72
# 12        12      Cape Town      ZA -33.9258   18.4232     75.90        68
# 14        14     Esmeraldas      BR -19.7625  -44.3139     79.11        81
# 19        19  Alice Springs      AU -23.7000  133.8833     88.21        40
# ..       ...            ...     ...      ...       ...       ...       ...
# 640      640     Maningrida      AU -12.0667  134.2667     79.47        86
# 647      647      Innisfail      AU -17.5333  146.0333     76.35        92
# 656      656         Cosala      MX  24.4125 -106.6908     79.41        21
# 657      657         Alugan      PH  12.2188  125.4808     78.96        87
# 659      659    Saint-Louis      SN  16.3333  -15.0000     80.04        13
#
#      Cloudiness  Wind Speed weather_description
# 2            40       11.50    scattered clouds
# 7           100       16.87     overcast clouds
# 12            0       11.01           clear sky
# 14           50        6.04    scattered clouds
# 19            3        3.00           clear sky
# ..          ...         ...                 ...
# 640         100        5.64          light rain
# 647         100        4.41          light rain
# 656           0        5.35           clear sky
# 657          87        0.54     overcast clouds
# 659         100        9.91     overcast clouds
#
# [167 rows x 10 columns]

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# YOUR CODE HERE

clean_travel_cities=preferred_cities_df.dropna()
# Display sample data
# YOUR CODE HERE
clean_travel_cities
# Out:
#      City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 2          2           Hilo      US  19.7297 -155.0900     82.13        69
# 7          7         Atuona      PF  -9.8000 -139.0333     78.69        72
# 12        12      Cape Town      ZA -33.9258   18.4232     75.90        68
# 14        14     Esmeraldas      BR -19.7625  -44.3139     79.11        81
# 19        19  Alice Springs      AU -23.7000  133.8833     88.21        40
# ..       ...            ...     ...      ...       ...       ...       ...
# 640      640     Maningrida      AU -12.0667  134.2667     79.47        86
# 647      647      Innisfail      AU -17.5333  146.0333     76.35        92
# 656      656         Cosala      MX  24.4125 -106.6908     79.41        21
# 657      657         Alugan      PH  12.2188  125.4808     78.96        87
# 659      659    Saint-Louis      SN  16.3333  -15.0000     80.04        13
#
#      Cloudiness  Wind Speed weather_description
# 2            40       11.50    scattered clouds
# 7           100       16.87     overcast clouds
# 12            0       11.01           clear sky
# 14           50        6.04    scattered clouds
# 19            3        3.00           clear sky
# ..          ...         ...                 ...
# 640         100        5.64          light rain
# 647         100        4.41          light rain
# 656           0        5.35           clear sky
# 657          87        0.54     overcast clouds
# 659         100        9.91     overcast clouds
#
# [167 rows x 10 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
# YOUR CODE HERE
hotel_df=clean_travel_cities[["City", "Country", "Max Temp", "weather_description", "Lat", "Lng"]].copy()
hotel_df
# Out:
#               City Country  Max Temp weather_description      Lat       Lng
# 2             Hilo      US     82.13    scattered clouds  19.7297 -155.0900
# 7           Atuona      PF     78.69     overcast clouds  -9.8000 -139.0333
# 12       Cape Town      ZA     75.90           clear sky -33.9258   18.4232
# 14      Esmeraldas      BR     79.11    scattered clouds -19.7625  -44.3139
# 19   Alice Springs      AU     88.21           clear sky -23.7000  133.8833
# ..             ...     ...       ...                 ...      ...       ...
# 640     Maningrida      AU     79.47          light rain -12.0667  134.2667
# 647      Innisfail      AU     76.35          light rain -17.5333  146.0333
# 656         Cosala      MX     79.41           clear sky  24.4125 -106.6908
# 657         Alugan      PH     78.96     overcast clouds  12.2188  125.4808
# 659    Saint-Louis      SN     80.04     overcast clouds  16.3333  -15.0000
#
# [167 rows x 6 columns]

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
# YOUR CODE HERE
hotel_df["Hotel Name"]= ""

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#               City Country  Max Temp weather_description      Lat       Lng  \
# 2             Hilo      US     82.13    scattered clouds  19.7297 -155.0900
# 7           Atuona      PF     78.69     overcast clouds  -9.8000 -139.0333
# 12       Cape Town      ZA     75.90           clear sky -33.9258   18.4232
# 14      Esmeraldas      BR     79.11    scattered clouds -19.7625  -44.3139
# 19   Alice Springs      AU     88.21           clear sky -23.7000  133.8833
# ..             ...     ...       ...                 ...      ...       ...
# 640     Maningrida      AU     79.47          light rain -12.0667  134.2667
# 647      Innisfail      AU     76.35          light rain -17.5333  146.0333
# 656         Cosala      MX     79.41           clear sky  24.4125 -106.6908
# 657         Alugan      PH     78.96     overcast clouds  12.2188  125.4808
# 659    Saint-Louis      SN     80.04     overcast clouds  16.3333  -15.0000
#
#     Hotel Name
# 2
# 7
# 12
# 14
# 19
# ..         ...
# 640
# 647
# 656
# 657
# 659
#
# [167 rows x 7 columns]

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address =  requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address =  name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Hilo - nearest hotel: Dolphin Bay Hotel
# Atuona - nearest hotel: Pearl Resort
# Cape Town - nearest hotel: Townhouse Hotel
# Esmeraldas - nearest hotel: No hotel found
# Alice Springs - nearest hotel: Aurora Alice Springs
# Kapaa - nearest hotel: Pono Kai Resort
# Sabanagrande - nearest hotel: Hotel Las Olas de Malambo
# Kavieng - nearest hotel: Kavieng Hotel
# Anito - nearest hotel: No hotel found
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Vaini - nearest hotel: Keleti International Resort
# Avarua - nearest hotel: Paradise Inn
# Cayenne - nearest hotel: Central Hôtel
# Ler - nearest hotel: Green Hotel
# Yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# Santa Cruz - nearest hotel: Aviador Hotel Boutique
# Kieta - nearest hotel: No hotel found
# Santiago - nearest hotel: apart arturo prat
# Batticaloa - nearest hotel: Lake View Hotel
# Mahebourg - nearest hotel: Grand Bel Air
# Saint-Joseph - nearest hotel: No hotel found
# Saint-Philippe - nearest hotel: Le Baril
# Tsabong - nearest hotel: No hotel found
# Mount Isa - nearest hotel: Ibis Styles
# Kloulklubed - nearest hotel: The Adventures Inn
# Bathsheba - nearest hotel: Atlantis Hotel
# Granville - nearest hotel: APX Parramatta
# Villa Del Rosario - nearest hotel: Acapulco
# Codrington - nearest hotel: No hotel found
# Sorong - nearest hotel: Hotel Membramo Marina
# Sao Filipe - nearest hotel: Bela Vista
# Palu - nearest hotel: Ujung Pandang Hotel
# Acapulco - nearest hotel: Hotel del Valle
# Prainha - nearest hotel: No hotel found
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Juntas - nearest hotel: Hospedaje El Encanto
# Santa Rosa - nearest hotel: JARS RESORT
# Port-Gentil - nearest hotel: Tara-Mé
# Nobres - nearest hotel: No hotel found
# Mahibadhoo - nearest hotel: Coral View Inn
# Pisco - nearest hotel: La Portada
# Pouembout - nearest hotel: No hotel found
# Georgetown - nearest hotel: Page 63 hostel
# Praia - nearest hotel: Casa Sodadi
# Poum - nearest hotel: No hotel found
# Labuan - nearest hotel: Labuan Avenue Hotel
# Arraial Do Cabo - nearest hotel: No hotel found
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Coro - nearest hotel: Urumaco Suite
# Cabedelo - nearest hotel: No hotel found
# Nouakchott - nearest hotel: فندق أدرار
# Hithadhoo - nearest hotel: Pebbles Inn
# Faanui - nearest hotel: Oa Oa Lodge
# Butaritari - nearest hotel: No hotel found
# Ballina - nearest hotel: Ballina Beach Resort
# Omboue - nearest hotel: Georges Faustin Aurat
# Petatlan - nearest hotel: No hotel found
# Puerto Narino - nearest hotel: Eco Hotel Euare
# Neiafu - nearest hotel: Port Wine Guest House
# Port Hedland - nearest hotel: The Esplanade Hotel
# Lakatoro - nearest hotel: No hotel found
# Inhambane - nearest hotel: Hotel de Inhambane
# Canberra - nearest hotel: Rydges Lakeside
# Gamba - nearest hotel: No hotel found
# Kavaratti - nearest hotel: No hotel found
# Hobyo - nearest hotel: No hotel found
# Ho Chi Minh City - nearest hotel: Khách Sạn Hoàng Nam
# Bambous Virieux - nearest hotel: No hotel found
# Karratha - nearest hotel: Karratha International Hotel
# Placido De Castro - nearest hotel: No hotel found
# George Town - nearest hotel: Page 63 hostel
# Roebourne - nearest hotel: No hotel found
# Maraa - nearest hotel: No hotel found
# Port Moresby - nearest hotel: The Sanctuary Hotel and Spa
# San Patricio - nearest hotel: No hotel found
# Noumea - nearest hotel: Hotel Gondwana
# Lazaro Cardenas - nearest hotel: Hotel Sol del Pacífico
# Warri - nearest hotel: Warri Sapele Road
# Ligayan - nearest hotel: No hotel found
# Micheweni - nearest hotel: No hotel found
# Machali - nearest hotel: Hotel Boutique Il Giardino
# Tual - nearest hotel: Suita
# Barabai - nearest hotel: Hotel Bouraq
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Sumenep - nearest hotel: No hotel found
# Chigorodo - nearest hotel: Gran Hotel Principal
# Vila Velha - nearest hotel: Hotel Prainha
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Oistins - nearest hotel: The Abidah By Accra
# Dingle - nearest hotel: No hotel found
# Saint-Georges - nearest hotel: Deyna's City Inn
# Angoram - nearest hotel: No hotel found
# Angoche - nearest hotel: Hotel Quirimbas
# Touros - nearest hotel: Pousada Atlântico
# Buchanan - nearest hotel: Phillipmena's Guesthouse
# Waingapu - nearest hotel: HOTEL SANDLEWOOD
# Itarema - nearest hotel: Pousada Oásis
# Kiama - nearest hotel: Nova Kiama
# Luzon - nearest hotel: No hotel found
# Kailua - nearest hotel: No hotel found
# Bambari - nearest hotel: No hotel found
# Mutis - nearest hotel: Hotel Pacífico Azul
# Porto Novo - nearest hotel: Hôtel 6500 CFA
# Mackay - nearest hotel: Mackay Oceanside Central Apartment Hotel
# Honiara - nearest hotel: King Solomon Hotel
# Tacuarembo - nearest hotel: Hotel Carlos Gardel
# Bubaque - nearest hotel: Chez Julio
# Padang - nearest hotel: losmen Surya
# Axim - nearest hotel: Axim Beach Hotel
# Vanimo - nearest hotel: CBC Guesthouse
# Garissa - nearest hotel: Hiddig Hotel
# Alofi - nearest hotel: No hotel found
# Pochutla - nearest hotel: Posada San Jose
# Fonte Boa - nearest hotel: No hotel found
# Portel - nearest hotel: No hotel found
# Jaque - nearest hotel: No hotel found
# Fare - nearest hotel: hôtel Maitai Lapita Village
# Benjamin Constant - nearest hotel: No hotel found
# San Andres - nearest hotel: Hotel Decameron Isleño
# Pitimbu - nearest hotel: Pousada Brisa Mar
# Viedma - nearest hotel: Níjar
# Kununurra - nearest hotel: Kununurra Country Club Resort
# Puerto Suarez - nearest hotel: No hotel found
# Ilhabela - nearest hotel: Vila Kebaya
# Amahai - nearest hotel: No hotel found
# Anaco - nearest hotel: Hotel Muñíz
# Tautira - nearest hotel: No hotel found
# Orocue - nearest hotel: No hotel found
# Luanda - nearest hotel: Hotel Forum
# Nabire - nearest hotel: Hotel Anggrek
# Acarau - nearest hotel: No hotel found
# Boyolangu - nearest hotel: No hotel found
# Santa Maria - nearest hotel: Hotel Morotin
# Mayumba - nearest hotel: Résidence Hôtelière Fabso
# Vallenar - nearest hotel: Hotel del Marqués
# Byron Bay - nearest hotel: Lord Byron Resort
# Inirida - nearest hotel: Residencias El Turista del Guainia
# Malakal - nearest hotel: No hotel found
# San Luis - nearest hotel: Hotel Dos Venados
# Beira - nearest hotel: Hotel Savoy
# Kudahuvadhoo - nearest hotel: No hotel found
# Buluang - nearest hotel: No hotel found
# Souillac - nearest hotel: Hotel SkylineInn
# Simbahan - nearest hotel: No hotel found
# Dhidhdhoo - nearest hotel: No hotel found
# Kralendijk - nearest hotel: Hotel Bonaire Inn
# Boueni - nearest hotel: La Case Robinson
# Saint-Pierre - nearest hotel: Tropic Hotel
# Tecoanapa - nearest hotel: No hotel found
# Lhokseumawe - nearest hotel: Vina Vira Hotel
# Samana - nearest hotel: Hotel Cotubanamá
# Machiques - nearest hotel: Hotel Paramaconí
# Gorontalo - nearest hotel: Grand City Hotel
# Samarai - nearest hotel: No hotel found
# Sola - nearest hotel: No hotel found
# Mandera - nearest hotel: Kornesh Hotel and Lodging
# Atambua - nearest hotel: Hotel Matahari
# Kimbe - nearest hotel: Kimbe Bay Hotel
# Belmonte - nearest hotel: No hotel found
# Kinablangan - nearest hotel: No hotel found
# San Policarpo - nearest hotel: No hotel found
# Maningrida - nearest hotel: No hotel found
# Innisfail - nearest hotel: No hotel found
# Cosala - nearest hotel: Hotel Quinta Minera
# Alugan - nearest hotel: No hotel found
# Saint-Louis - nearest hotel: No hotel found
#               City Country  Max Temp weather_description      Lat       Lng  \
# 2             Hilo      US     82.13    scattered clouds  19.7297 -155.0900
# 7           Atuona      PF     78.69     overcast clouds  -9.8000 -139.0333
# 12       Cape Town      ZA     75.90           clear sky -33.9258   18.4232
# 14      Esmeraldas      BR     79.11    scattered clouds -19.7625  -44.3139
# 19   Alice Springs      AU     88.21           clear sky -23.7000  133.8833
# ..             ...     ...       ...                 ...      ...       ...
# 640     Maningrida      AU     79.47          light rain -12.0667  134.2667
# 647      Innisfail      AU     76.35          light rain -17.5333  146.0333
# 656         Cosala      MX     79.41           clear sky  24.4125 -106.6908
# 657         Alugan      PH     78.96     overcast clouds  12.2188  125.4808
# 659    Saint-Louis      SN     80.04     overcast clouds  16.3333  -15.0000
#
#                Hotel Name
# 2       Dolphin Bay Hotel
# 7            Pearl Resort
# 12        Townhouse Hotel
# 14         No hotel found
# 19   Aurora Alice Springs
# ..                    ...
# 640        No hotel found
# 647        No hotel found
# 656   Hotel Quinta Minera
# 657        No hotel found
# 659        No hotel found
#
# [167 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
# YOUR CODE HERE
clean_hotel_df=hotel_df.loc[hotel_df["Hotel Name"]!= "No hotel found"]
# Display sample data
# YOUR CODE HERE
clean_hotel_df
# Out:
#               City Country  Max Temp weather_description      Lat       Lng  \
# 2             Hilo      US     82.13    scattered clouds  19.7297 -155.0900
# 7           Atuona      PF     78.69     overcast clouds  -9.8000 -139.0333
# 12       Cape Town      ZA     75.90           clear sky -33.9258   18.4232
# 19   Alice Springs      AU     88.21           clear sky -23.7000  133.8833
# 35           Kapaa      US     81.48    scattered clouds  22.0752 -159.3190
# ..             ...     ...       ...                 ...      ...       ...
# 607      Gorontalo      ID     76.64       broken clouds   0.5412  123.0595
# 613        Mandera      KE     77.45     overcast clouds   3.9366   41.8670
# 615        Atambua      ID     76.78     overcast clouds  -9.1061  124.8925
# 630          Kimbe      PG     78.03     overcast clouds  -5.5502  150.1429
# 656         Cosala      MX     79.41           clear sky  24.4125 -106.6908
#
#                     Hotel Name
# 2            Dolphin Bay Hotel
# 7                 Pearl Resort
# 12             Townhouse Hotel
# 19        Aurora Alice Springs
# 35             Pono Kai Resort
# ..                         ...
# 607           Grand City Hotel
# 613  Kornesh Hotel and Lodging
# 615             Hotel Matahari
# 630            Kimbe Bay Hotel
# 656        Hotel Quinta Minera
#
# [110 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
# YOUR CODE HERE
output_data_file= "/Users/arashyousefi/Desktop/Analysis Project/Module-6/Vacation_Search/WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file)

# YOUR CODE HERE

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
# YOUR CODE HERE
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["City", "Country","weather_description"]
)
# Display the map
# YOUR CODE HERE
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,weather_description)
